# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Sravan\Downloads\Assignments')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## UNIVARIATE

# %%
sns.countplot(df['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## BI_VARIATE

# %%
sns.countplot(data=df,x='Geography',hue='Gender')

# %% [markdown]
# ## MULTIVARIATE

# %%
sns.pairplot(data=df[['Age','Tenure','EstimatedSalary','CreditScore','Balance','Geography']],hue='Geography')

# %% [markdown]
# ## Descriptive Statistics

# %%
df['Age'].median(), df['Balance'].mean()
# Out:
# (37.0, 76485.889288)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df[df['Age']>40]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 1             2    15647311         Hill          608     Spain  Female   41
# 2             3    15619304         Onio          502    France  Female   42
# 4             5    15737888     Mitchell          850     Spain  Female   43
# 5             6    15574012          Chu          645     Spain    Male   44
# ...         ...         ...          ...          ...       ...     ...  ...
# 9981       9982    15672754     Burbidge          498   Germany    Male   42
# 9982       9983    15768163      Griffin          655   Germany  Female   46
# 9986       9987    15581736     Bartlett          673   Germany    Male   47
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 4          2  125510.82              1          1               1
# 5          8  113755.78              2          1               0
# ...      ...        ...            ...        ...             ...
# 9981       3  152039.70              1          1               1
# 9982       7  137145.12              1          1               0
# 9986       1  183579.54              2          0               1
# 9991       4   88381.21              1          1               0
# 9998       3   75075.31              2          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 4            79084.10       0
# 5           149756.71       1
# ...               ...     ...
# 9981         53445.17       1
# 9982        115146.40       1
# 9986         34047.54       0
# 9991         69384.71       1
# 9998         92888.52       1
#
# [3581 rows x 14 columns]

# %% [markdown]
# ## Handle The Missing Values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %%
import pandas as pd
data = pd.read_csv("/content/Churn_Modelling.csv") 
bool_series = pd.isnull(data["Gender"])
data[bool_series]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
import pandas as pd
data = pd.read_csv("/content/Churn_Modelling.csv") 
bool_series = pd.notnull(data["Gender"])
data[bool_series]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# ## FINDING OUTLIERS

# %%
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## REPLACING OUTLIERS

# %%
median = float(df['Age'].median())
df["Age"] = np.where(df["Age"] > median, median, df['Age'])
sns.boxplot(df['Age'],data=df)

# %% [markdown]
# ## CATERGORICAL COLUMN AND ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
le = LabelEncoder()

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
count(df['Geography'])
# Out:
# Counter({'France': 5014, 'Spain': 2477, 'Germany': 2509})

# %%
df['Geography']=le.fit_transform(df['Geography'])

# %%
count(df['Geography'])
# Out:
# Counter({0: 5014, 2: 2477, 1: 2509})

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619          0  Female  37.0
# 1             2    15647311       Hill          608          2  Female  37.0
# 2             3    15619304       Onio          502          0  Female  37.0
# 3             4    15701354       Boni          699          0  Female  37.0
# 4             5    15737888   Mitchell          850          2  Female  37.0
# ...         ...         ...        ...          ...        ...     ...   ...
# 9995       9996    15606229   Obijiaku          771          0    Male  37.0
# 9996       9997    15569892  Johnstone          516          0    Male  35.0
# 9997       9998    15584532        Liu          709          0  Female  36.0
# 9998       9999    15682355  Sabbatini          772          1    Male  37.0
# 9999      10000    15628319     Walker          792          0  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df['Surname'].unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %%
count(df['Surname'])
# Out:
# Counter({'Hargrave': 1,
#          'Hill': 17,
#          'Onio': 8,
#          'Boni': 14,
#          'Mitchell': 20,
#          'Chu': 22,
#          'Bartlett': 4,
#          'Obinna': 2,
#          'He': 18,
#          'H?': 19,
#          'Bearce': 1,
#          'Andrews': 6,
#          'Kay': 5,
#          'Chin': 16,
#          'Scott': 29,
#          'Goforth': 1,
#          'Romeo': 1,
#          'Henderson': 16,
#          'Muldrow': 1,
#          'Hao': 12,
#          'McDonald': 19,
#          'Dellucci': 13,
#          'Gerasimov': 2,
#          'Mosman': 1,
#          'Yen': 14,
#          'Maclean': 24,
#          'Young': 20,
#          'Nebechi': 6,
#          'McWilliams': 2,
#          'Lucciano': 11,
#          'Azikiwe': 5,
#          'Odinakachukwu': 4,
#          'Sanderson': 4,
#          'Maggard': 2,
#          'Clements': 9,
#          'Lombardo': 15,
#          'Watson': 20,
#          'Lorenzo': 12,
#          'Armstrong': 1,
#          'Cameron': 19,
#          'Hsiao': 8,
#          'Clarke': 4,
#          'Osborne': 6,
#          'Lavine': 1,
#          'Bianchi': 10,
#          'Tyler': 4,
#          'Martin': 29,
#          'Okagbue': 3,
#          'Yin': 11,
#          'Buccho': 14,
#          'Chidiebele': 3,
#          'Trevisani': 20,
#          "O'Brien": 4,
#          'Parkhill': 4,
#          'Yoo': 1,
#          'Phillipps': 1,
#          'Tsao': 17,
#          'Endrizzi': 17,
#          "T'ien": 18,
#          'Velazquez': 1,
#          'Hunter': 13,
#          'Clark': 16,
#          'Jeffrey': 1,
#          'Pirozzi': 14,
#          'Jackson': 9,
#          'Hammond': 3,
#          'Brownless': 2,
#          'Chibugo': 5,
#          'Glauert': 1,
#          'Pisano': 16,
#          'Konovalova': 4,
#          'McKee': 1,
#          'Palermo': 12,
#          'Ballard': 3,
#          'Wallace': 19,
#          'Cavenagh': 2,
#          'Hu': 12,
#          'Read': 3,
#          'Bushell': 1,
#          'Postle': 1,
#          'Buley': 1,
#          'Leonard': 5,
#          'Mills': 7,
#          'Onyeorulu': 5,
#          'Beit': 1,
#          'Ndukaku': 3,
#          'Gant': 1,
#          'Rowley': 7,
#          'Sharpe': 3,
#          'Heap': 1,
#          'Ritchie': 11,
#          'Cole': 4,
#          'Capon': 14,
#          'Fiorentini': 14,
#          'Graham': 20,
#          'Yuille': 1,
#          'Allard': 1,
#          'Fanucci': 23,
#          'Fu': 16,
#          'Hung': 15,
#          'Bradley': 8,
#          'Dunbabin': 1,
#          'Mauldon': 1,
#          'Stiger': 1,
#          'Parsons': 6,
#          'Walkom': 1,
#          "T'ang": 13,
#          'Eremenko': 1,
#          'Rowntree': 2,
#          'Thorpe': 6,
#          'Chiemela': 5,
#          'Ko': 19,
#          'Welch': 5,
#          'Duncan': 19,
#          'Chidozie': 5,
#          'Wu': 16,
#          'Culbreth': 1,
#          'Kennedy': 20,
#          'Calabresi': 16,
#          'Zetticci': 11,
#          'Fuller': 7,
#          'MacDonald': 13,
#          'Piccio': 13,
#          'Fernie': 1,
#          'Kaodilinakachukwu': 4,
#          'Cocci': 17,
#          'Alekseeva': 4,
#          'Chinweike': 3,
#          'Arthur': 1,
#          'Li': 12,
#          'Ma': 23,
#          'Chia': 14,
#          'Vasin': 2,
#          'Groves': 1,
#          'Tien': 18,
#          'Forwood': 1,
#          'Greeves': 1,
#          'Taylor': 15,
#          'Madukwe': 6,
#          'Bennelong': 1,
#          'Olisanugo': 6,
#          'Chukwufumnanya': 5,
#          'Harris': 5,
#          'Morgan': 4,
#          'Alexeeva': 6,
#          'Metcalfe': 2,
#          'Humphries': 5,
#          'Milne': 13,
#          'Chou': 10,
#          'Clayton': 3,
#          'Chigolum': 4,
#          'Wilkinson': 4,
#          'Wei': 19,
#          'Treacy': 1,
#          'Taverner': 1,
#          'Sherman': 2,
#          'Taubman': 1,
#          'Robinson': 12,
#          'Pinto': 14,
#          'Wood': 15,
#          'Hawkins': 7,
#          'Sun': 21,
#          'Yost': 1,
#          'Ting': 12,
#          'Rowe': 8,
#          'Ho': 11,
#          'Okechukwu': 7,
#          'Campbell': 13,
#          'Ashbolt': 2,
#          'Rozier': 1,
#          'Hsia': 18,
#          'Ogbonnaya': 5,
#          'Chang': 14,
#          "T'ao": 13,
#          'Ford': 6,
#          'Marshall': 15,
#          'Tsai': 7,
#          'Onwumelu': 7,
#          'Golovanov': 2,
#          'Potts': 1,
#          'Crawford': 19,
#          'Aleshire': 1,
#          'Moran': 7,
#          'Samsonova': 3,
#          'Jenkins': 4,
#          'Volkov': 1,
#          'Chiemezie': 4,
#          'Jude': 1,
#          'Onuora': 3,
#          'Ginikanwa': 8,
#          'Ku': 16,
#          'Collins': 5,
#          'Hackett': 2,
#          'Dike': 3,
#          'Trevisano': 16,
#          'Tan': 14,
#          'Glassman': 1,
#          'Miller': 20,
#          'Kornilova': 3,
#          'Marchesi': 9,
#          'Millar': 13,
#          'Shih': 25,
#          'Hay': 8,
#          'Yang': 13,
#          'McIntyre': 17,
#          'Stevenson': 16,
#          'Poole': 4,
#          'Bagley': 1,
#          "Ch'ien": 13,
#          'Cattaneo': 15,
#          "O'Sullivan": 3,
#          'Lucas': 8,
#          'Ringrose': 1,
#          'Freeman': 8,
#          'Sergeyev': 3,
#          'Fiore': 1,
#          'Smith': 32,
#          'Dumetochukwu': 4,
#          'Pacheco': 1,
#          'Synnot': 2,
#          'Johnston': 17,
#          'Stevens': 6,
#          'Grant': 17,
#          'Barnes': 6,
#          'McIntosh': 10,
#          'Madison': 2,
#          'Ifesinachi': 2,
#          'Glazkov': 1,
#          'Dimauro': 1,
#          'Wieck': 1,
#          'Liao': 12,
#          'Hughes': 20,
#          'Morrison': 12,
#          'Matveyeva': 5,
#          'Cheatham': 2,
#          'Yao': 16,
#          'Kirkland': 1,
#          'Rose': 7,
#          'Jess': 1,
#          'Ifeajuna': 3,
#          'Morton': 1,
#          'Rossi': 14,
#          'Reppert': 1,
#          'Kang': 14,
#          "Ch'iu": 16,
#          'Wallis': 3,
#          'Fielding': 1,
#          'Dulhunty': 1,
#          'Bevington': 1,
#          'Boyle': 17,
#          'Newton': 2,
#          'Bowman': 1,
#          'Dubinina': 3,
#          'Toscani': 13,
#          'Chiazagomekpere': 7,
#          'Allen': 6,
#          "K'ung": 12,
#          'Wilsmore': 1,
#          'Hargreaves': 7,
#          'Huang': 12,
#          'Wallwork': 1,
#          'Davidson': 17,
#          "O'Donnell": 5,
#          'Nnachetam': 7,
#          'Ahmed': 4,
#          'Booth': 6,
#          'Chuang': 14,
#          'Shao': 12,
#          'Johnson': 22,
#          'French': 4,
#          'Efremov': 3,
#          'Hartley': 3,
#          'Calabrese': 13,
#          'Chiu': 17,
#          'Brennan': 6,
#          'Onwuatuegwu': 3,
#          'Hewitt': 2,
#          'Balashov': 6,
#          'Doyle': 6,
#          'Pokrovskii': 1,
#          'Russo': 7,
#          'Skinner': 4,
#          'Robertson': 16,
#          'Atkinson': 6,
#          'McEncroe': 1,
#          'Pearson': 3,
#          'Gordon': 19,
#          "Ts'ai": 15,
#          'Lung': 19,
#          'Yuan': 13,
#          'Pardey': 1,
#          'Tai': 12,
#          'Mazzanti': 15,
#          'L?': 14,
#          'Beach': 1,
#          'Hsieh': 16,
#          'Faulkner': 2,
#          'Knowles': 4,
#          'Day': 4,
#          'Hsueh': 14,
#          'Nwabugwu': 7,
#          'Kerr': 20,
#          'Marrero': 1,
#          'White': 23,
#          'Brown': 26,
#          'Russell': 12,
#          'Seleznyov': 4,
#          'Yusupova': 3,
#          'Foley': 1,
#          'Ikedinachukwu': 3,
#          'Power': 9,
#          'Amos': 1,
#          'Reed': 5,
#          'Simmons': 14,
#          'Ricci': 9,
#          'West': 6,
#          'Chen': 8,
#          'Madukaego': 4,
#          'Ibrahimova': 3,
#          'Nolan': 2,
#          'Blair': 3,
#          'Monaldo': 8,
#          'Sutherland': 14,
#          'Briggs': 6,
#          'Gregory': 6,
#          'Angelo': 11,
#          'Gardiner': 5,
#          'Distefano': 1,
#          'Farrell': 3,
#          'Milano': 8,
#          'Boyd': 3,
#          'Onyemaechi': 1,
#          'Black': 15,
#          'Oliver': 5,
#          'Greco': 17,
#          'Whitehead': 4,
#          'Ikemefuna': 4,
#          'Onyeoruru': 3,
#          'Cunningham': 10,
#          'Demidov': 1,
#          'Celis': 1,
#          'Cheng': 13,
#          'Knight': 8,
#          'Morin': 1,
#          'Outhwaite': 1,
#          'Tung': 10,
#          'Pai': 19,
#          'Carpenter': 10,
#          'Fennell': 2,
#          'Fontaine': 1,
#          'Pratt': 2,
#          'Franklin': 7,
#          'McKenzie': 16,
#          'Pino': 1,
#          'Fisk': 2,
#          'Chiang': 14,
#          'Moseley': 1,
#          'Hsiung': 15,
#          'Heath': 5,
#          'De Salis': 3,
#          'Richardson': 2,
#          'Fitch': 1,
#          'Estes': 1,
#          'Lattimore': 1,
#          'Chung': 17,
#          'Utz': 1,
#          'Nwachinemelu': 4,
#          'Kuznetsova': 1,
#          'Pisani': 13,
#          'Manna': 17,
#          'Collier': 5,
#          'Carr': 5,
#          'Hs?': 15,
#          'Findlay': 17,
#          'Chukwuemeka': 11,
#          'Genovese': 25,
#          'Swift': 4,
#          'Ugoji': 3,
#          'Parkinson': 1,
#          'Ross': 18,
#          'Oleary': 1,
#          'Turnbull': 5,
#          'Uspensky': 6,
#          'Cook': 5,
#          'Newbold': 1,
#          'Uchechukwu': 3,
#          "Ch'en": 10,
#          'Hilton': 2,
#          'Sal': 14,
#          'Eluemuno': 7,
#          'Titus': 1,
#          'Lettiere': 12,
#          'Templeman': 1,
#          'Chibuzo': 4,
#          'Evans': 10,
#          'Enyinnaya': 6,
#          'Brookes': 8,
#          'Padovano': 11,
#          'Hare': 1,
#          'Muir': 12,
#          'Elewechi': 2,
#          'Ankudinov': 2,
#          'Nwokike': 2,
#          'Atkins': 7,
#          'Burns': 18,
#          'Obiuto': 6,
#          'George': 3,
#          'Lewis': 5,
#          'Dalrymple': 2,
#          'Carslaw': 3,
#          'Kirby': 3,
#          'Houghton': 4,
#          'Westerberg': 1,
#          'Hale': 5,
#          'Kryukova': 2,
#          'Sopuluchukwu': 3,
#          'Barry': 7,
#          'Selezneva': 1,
#          'Chizuoke': 5,
#          'Lueck': 1,
#          'Udinese': 11,
#          'Udobata': 4,
#          'Outlaw': 1,
#          'Lo': 20,
#          'King': 18,
#          'Forbes': 16,
#          'Macleod': 13,
#          'Gibbs': 3,
#          'Isayev': 1,
#          'Belstead': 2,
#          'Vassiliev': 2,
#          'Schneider': 3,
#          'Knipe': 1,
#          'Macartney': 2,
#          'Watts': 5,
#          'Humphreys': 2,
#          'Chesnokova': 3,
#          'Kung': 16,
#          'Lu': 22,
#          'Nkemakolam': 5,
#          'Walton': 8,
#          'Baldwin': 3,
#          'Mai': 21,
#          'Ferreira': 1,
#          'Ukaegbunam': 4,
#          'De Luca': 10,
#          'Davide': 11,
#          'Kodilinyechukwu': 7,
#          'Little': 3,
#          'Paterson': 11,
#          'Han': 11,
#          'Ijendu': 6,
#          'Reichard': 1,
#          'Price': 5,
#          'Bruce': 7,
#          'Sumrall': 1,
#          'Lazarev': 5,
#          'Wentworth-Shields': 1,
#          'Mackenzie': 9,
#          'Pendergrass': 1,
#          'Billson': 1,
#          'Teng': 15,
#          'Moretti': 9,
#          'Jordan': 2,
#          "Ts'ao": 12,
#          "Ch'ang": 17,
#          'Obialo': 7,
#          'Gray': 13,
#          'Lin': 18,
#          'Hopkins': 2,
#          'Dobson': 1,
#          'McKay': 19,
#          'Revell': 1,
#          'Rickards': 1,
#          'Begum': 2,
#          'Onyinyechukwuka': 3,
#          'Zuyev': 2,
#          'Nwankwo': 9,
#          'Okwuadigbo': 5,
#          'Chan': 7,
#          'Buchi': 2,
#          'Lombardi': 11,
#          'Uchenna': 3,
#          'Coffman': 1,
#          'Alexandrova': 3,
#          'Fallaci': 11,
#          'Hudson': 8,
#          'Stout': 1,
#          'Burke': 7,
#          'Chadwick': 1,
#          'Lawrence': 7,
#          'Bellucci': 12,
#          'Harper': 2,
#          'Moss': 13,
#          'Avdeyeva': 2,
#          'Lynton': 1,
#          'Gether': 2,
#          'Larionova': 3,
#          'Loggia': 12,
#          'Steinhoff': 1,
#          'Guerra': 1,
#          'Craig': 11,
#          'Lazareva': 3,
#          'Alderete': 1,
#          'Rahman': 4,
#          'McMillan': 14,
#          'Pickering': 6,
#          'Mirams': 1,
#          'Douglas': 15,
#          'Jideofor': 5,
#          'Bell': 11,
#          'Mairinger': 1,
#          'Pagnotto': 11,
#          'Feng': 17,
#          'Donaldson': 12,
#          'Chambers': 8,
#          'Marcelo': 10,
#          'Ejimofor': 4,
#          'Dale': 7,
#          'Pokrovsky': 3,
#          'Stonebraker': 1,
#          'Liang': 14,
#          'Anderson': 19,
#          'Christian': 3,
#          'Mao': 18,
#          'Sagese': 9,
#          'Fleming': 18,
#          'Grubb': 1,
#          'Napolitani': 13,
#          'Anenechi': 3,
#          'Chandler': 4,
#          'Howells': 8,
#          'Akeroyd': 1,
#          'Uwaezuoke': 4,
#          'Loyau': 2,
#          'Small': 2,
#          'Bledsoe': 1,
#          'Kao': 20,
#          'Wickens': 1,
#          'Wertheim': 1,
#          'Jarvis': 3,
#          "P'an": 8,
#          'Repina': 3,
#          'Pugliesi': 5,
#          'Blakey': 1,
#          'Nucci': 8,
#          'Higinbotham': 1,
#          'Achebe': 3,
#          'Dobie': 2,
#          'Maccallum': 1,
#          'Watkins': 5,
#          'Mitchel': 1,
#          'Ferdinand': 1,
#          'Otitodilinna': 3,
#          'Mamelu': 3,
#          'Beneventi': 12,
#          'Perrodin': 1,
#          'Chinagorom': 3,
#          'Napolitano': 9,
#          'Edgar': 1,
#          'Walker': 28,
#          'Steele': 6,
#          'Elkins': 1,
#          'Toscano': 11,
#          'Savage': 5,
#          'Mordvinova': 4,
#          'Kent': 7,
#          'Cooper': 3,
#          'Mazzi': 13,
#          'Fisher': 1,
#          'Summers': 5,
#          'Brady': 4,
#          'Nicholls': 8,
#          'Golubov': 2,
#          'Oldham': 1,
#          'Kambinachi': 5,
#          'Chinwemma': 3,
#          'Olsen': 2,
#          'Jen': 12,
#          'Preston': 3,
#          'Ozioma': 4,
#          'Cody': 2,
#          'Ponomarev': 3,
#          'Milani': 11,
#          'Tang': 17,
#          'Romani': 10,
#          'Davis': 11,
#          'Onyemauchechukwu': 8,
#          'Gell': 1,
#          'Chiwetelu': 1,
#          'Kirillova': 2,
#          'Shaw': 17,
#          'Okwudilichukwu': 6,
#          'Onuoha': 3,
#          'Muecke': 1,
#          'Azubuike': 9,
#          'Nnonso': 7,
#          'Ashley': 1,
#          "Ts'ui": 19,
#          'Kenenna': 4,
#          'Beluchi': 2,
#          'Williamson': 14,
#          'Bobrov': 2,
#          'Pitts': 1,
#          'Standish': 1,
#          'Cartwright': 8,
#          'Johnstone': 16,
#          'Nikitina': 4,
#          'McElroy': 1,
#          'Shen': 20,
#          'Archer': 5,
#          'Otutodilinna': 6,
#          'Denisov': 3,
#          'Owens': 6,
#          "P'eng": 17,
#          'Verco': 1,
#          'Bergamaschi': 19,
#          'Outtrim': 1,
#          'Hou': 10,
#          'Galkin': 3,
#          'Echezonachukwu': 4,
#          'Munro': 11,
#          'Ball': 8,
#          'Virgo': 2,
#          'Tao': 11,
#          'Perez': 3,
#          'Fraser': 14,
#          'Alley': 1,
#          'Hooper': 3,
#          'Rice': 4,
#          'Cox': 9,
#          'Ikenna': 5,
#          'Alexander': 13,
#          'Piazza': 7,
#          'Ni': 10,
#          'Harker': 2,
#          'Chiabuotu': 3,
#          'Kuo': 10,
#          'Gallagher': 4,
#          'Zhirov': 3,
#          'Lloyd': 5,
#          'Palmer': 8,
#          "Ch'eng": 13,
#          'Avent': 1,
#          'Trentini': 7,
#          'Koehler': 1,
#          'Okoli': 3,
#          'Nwokezuike': 2,
#          'Artemiev': 3,
#          'Esposito': 13,
#          'Abbie': 1,
#          'Averyanov': 1,
#          'Unaipon': 1,
#          'Clamp': 1,
#          'Lim': 1,
#          'Wan': 17,
#          'Pettit': 1,
#          'Baresi': 7,
#          'Newbery': 1,
#          'Iheanacho': 2,
#          'Landry': 1,
#          'McGregor': 21,
#          'Pirogov': 2,
#          'Oguejiofor': 3,
#          'Ugochukwu': 6,
#          'Rohu': 1,
#          'Cary': 1,
#          "O'Loghlen": 1,
#          'Quinn': 4,
#          'Page': 8,
#          'Stanley': 6,
#          'Bednall': 3,
#          'She': 13,
#          'May': 4,
#          'Seabrook': 1,
#          'Herrera': 3,
#          'Kincaid': 1,
#          'Sleeman': 2,
#          'Artemieva': 3,
#          'Barwell': 1,
#          'Wright': 24,
#          'Moore': 22,
#          'Sung': 18,
#          'Mello': 1,
#          'Mistry': 3,
#          'Chukwukadibia': 5,
#          'Zikoranachidimma': 6,
#          'Oluchukwu': 7,
#          'Rivera': 2,
#          'Niu': 13,
#          'Bennett': 4,
#          'Wollstonecraft': 2,
#          'Thomsen': 1,
#          'Chinwendu': 6,
#          'James': 4,
#          'Lamb': 5,
#          'Olejuru': 3,
#          'Chiawuotu': 5,
#          'Yeates': 1,
#          'Thurgood': 2,
#          'Knupp': 1,
#          'Baryshnikov': 2,
#          'Shephard': 2,
#          'Avdeeva': 3,
#          'Hsu': 11,
#          'Buchanan': 1,
#          'Yeh': 25,
#          'Palazzi': 1,
#          'Y?an': 13,
#          'Schofield': 4,
#          'Wall': 9,
#          'Blackburn': 6,
#          'Wickham': 1,
#          'Bird': 4,
#          'Brizendine': 1,
#          "Ch'in": 13,
#          'Yusupov': 1,
#          'Jibunoh': 4,
#          'Wilder': 2,
#          'Nepean': 3,
#          'McNess': 1,
#          'Coles': 6,
#          'Benson': 8,
#          'Gilbert': 5,
#          'Wilhelm': 2,
#          'Sinclair': 15,
#          'Buckner': 1,
#          'Padovesi': 12,
#          'Palerma': 20,
#          'Pan': 19,
#          'Kenniff': 1,
#          'Spencer': 3,
#          'Lees': 4,
#          'David': 1,
#          'Hsing': 17,
#          'Ginn': 1,
#          'Sozonov': 2,
#          'Manfrin': 17,
#          'Artamonova': 2,
#          'Hansen': 4,
#          'Larsen': 1,
#          'Owen': 5,
#          'Murphy': 11,
#          'Ekechukwu': 2,
#          'Ayers': 4,
#          'Sanders': 7,
#          'Eberechukwu': 2,
#          'Bardin': 1,
#          'Talbot': 4,
#          'Goold': 1,
#          'Zikoranaudodimma': 1,
#          'Garner': 2,
#          'Naylor': 3,
#          'Fulton': 1,
#          'McCaffrey': 1,
#          'Zuev': 1,
#          'Fabro': 1,
#          'Chatfield': 1,
#          'Volkova': 7,
#          'Abramovich': 5,
#          'Chien': 12,
#          'Timms': 1,
#          'Williford': 1,
#          'Hamilton': 15,
#          'Su': 16,
#          'Akobundu': 7,
#          'Chukwuebuka': 4,
#          'Lampungmeiua': 1,
#          'Kline': 1,
#          'Riggs': 1,
#          'Davison': 7,
#          'Ingram': 4,
#          'Dilke': 2,
#          'Gibson': 17,
#          'Iadanza': 9,
#          'Hebert': 1,
#          'Jamieson': 20,
#          'Chiganu': 6,
#          'Burgess': 5,
#          'Woods': 10,
#          'Bluett': 1,
#          'Chapman': 5,
#          'Andrejew': 3,
#          'Spyer': 1,
#          'Philip': 2,
#          'Perry': 5,
#          'Fokine': 1,
#          'Mackay': 7,
#          'Maslova': 4,
#          'McLean': 7,
#          'Thompson': 21,
#          'Tisdall': 1,
#          'Onochie': 4,
#          'Mironova': 4,
#          'Ndubueze': 5,
#          'Stephenson': 9,
#          'Golubev': 5,
#          'Mullan': 1,
#          'Glover': 6,
#          'Northey': 1,
#          'Howarde': 1,
#          'Colman': 1,
#          'Butcher': 4,
#          'Wilkie': 1,
#          'Bray': 5,
#          'Ann': 1,
#          'Souter': 1,
#          'Medvedeva': 4,
#          'Onwudiwe': 2,
#          'Ferrari': 9,
#          'Hazon': 1,
#          'Hardy': 6,
#          'Dickson': 7,
#          'Holden': 5,
#          'Doherty': 9,
#          'Samuel': 1,
#          'Malloy': 1,
#          'Fitts': 1,
#          'Yefimova': 4,
#          'Abramov': 1,
#          'Demuth': 1,
#          'Lawless': 1,
#          'Brooks': 5,
#          'Ignatyeva': 3,
#          'Balmain': 1,
#          'Ecuyer': 1,
#          'Li Fonti': 11,
#          'Despeissis': 1,
#          'Williams': 12,
#          'Hancock': 7,
#          'Wilkins': 2,
#          'Longo': 11,
#          'Mancini': 11,
#          'Winter-Irving': 2,
#          'Stewart': 12,
#          'Murray': 15,
#          'Rischbieth': 1,
#          'Otutodilichukwu': 5,
#          'Thomas': 8,
#          'Whitworth': 2,
#          'Trentino': 12,
#          'McMasters': 1,
#          'Alekseyeva': 3,
#          'Baranova': 2,
#          'Yobachi': 5,
#          'Sorokina': 3,
#          'Ervin': 1,
#          'Vance': 1,
#          'Noble': 4,
#          'Milanesi': 12,
#          'Parkin': 5,
#          'Cremonesi': 12,
#          'Docherty': 8,
#          'Ugonna': 3,
#          'Bevan': 6,
#          "O'Neill": 1,
#          'Pham': 1,
#          'Osinachi': 5,
#          'Muravyov': 1,
#          'Igwebuike': 3,
#          'Zack': 1,
#          'Chidiegwu': 4,
#          'Lucchesi': 12,
#          'Yudin': 4,
#          'Wade': 6,
#          'Septimus': 1,
#          'Hargraves': 1,
#          'Sidorov': 3,
#          'Bunton': 1,
#          'Conti': 9,
#          'Sims': 5,
#          'Carter': 7,
#          'Dumetolisa': 2,
#          'Peng': 7,
#          'Drake-Brockman': 1,
#          'Tretiakov': 2,
#          'Lai': 13,
#          'Justice': 1,
#          'Osonduagwuike': 6,
#          'Ewing': 2,
#          'Tsou': 10,
#          'Ubanwa': 3,
#          'Kapustin': 2,
#          'Nnamutaezinwa': 5,
#          'Ferri': 16,
#          'Amechi': 4,
#          'Kirk': 1,
#          'Griffin': 5,
#          'Longstaff': 1,
#          'McWilliam': 1,
#          'Coffee': 1,
#          'Creswell': 1,
#          'Dodds': 1,
#          'Ewen': 1,
#          'Boniwell': 2,
#          'Vasilieva': 3,
#          'Kwemto': 4,
#          'Bocharova': 2,
#          'Morres': 1,
#          'Vogel': 1,
#          "T'an": 5,
#          'Wisdom': 2,
#          'Shahan': 1,
#          'Bryant': 7,
#          'Hayward': 5,
#          'Liu': 12,
#          'Greece': 9,
#          'Norman': 6,
#          'Chukwudi': 8,
#          'Fedorov': 4,
#          'Reid': 8,
#          'Wofford': 1,
#          'Stephens': 3,
#          'Frolov': 4,
#          'Fields': 2,
#          'Suffolk': 1,
#          'Judd': 1,
#          'Degtyarev': 3,
#          'Kinlaw': 1,
#          'Omeokachie': 4,
#          'Gorbunova': 3,
#          'Tikhonov': 2,
#          'Campa': 1,
#          'Donoghue': 1,
#          'Tuan': 19,
#          'Baxter': 4,
#          'Rogers': 4,
#          'Byrne': 5,
#          'Aitken': 8,
#          'Macintyre': 1,
#          'Simpson': 12,
#          'Praed': 1,
#          'Laurens': 1,
#          'Bykov': 1,
#          'Vorobyova': 4,
#          'Pirogova': 3,
#          'Sturt': 1,
#          'Panicucci': 7,
#          'Siciliani': 6,
#          'Lucchese': 10,
#          'Swaim': 1,
#          'Quinones': 1,
#          'Ludowici': 1,
#          'Larson': 1,
#          'Landman': 1,
#          'K?': 11,
#          'Alexeyeva': 5,
#          'Chukwualuka': 5,
#          'McCall': 1,
#          'Okeke': 6,
#          'Iloabuchi': 1,
#          'Nebechukwu': 7,
#          'Diribe': 3,
#          'Macgroarty': 1,
#          'Artemova': 2,
#          'Kelly': 12,
#          'Reilly': 7,
#          'Ojiofor': 5,
#          'Shelton': 1,
#          'Lange': 1,
#          'Hovell': 2,
#          'Espinosa': 1,
#          'Barbour': 1,
#          'Ozerova': 5,
#          'Ulyanova': 3,
#          'Steiner': 1,
#          'Akabueze': 8,
#          'Aleksandrova': 3,
#          'Griffiths': 2,
#          'McNeil': 1,
#          'Bruno': 12,
#          'Okorie': 2,
#          'Moen': 1,
#          'McGuigan': 1,
#          'Fancher': 1,
#          'Matthews': 6,
#          'Kaeppel': 2,
#          'Yudina': 4,
#          'Jamison': 1,
#          'Hardiman': 1,
#          'Woodard': 1,
#          'Chienezie': 6,
#          'Chineze': 4,
#          'Buckland': 2,
#          'Flannery': 1,
#          'Payne': 3,
#          'Vincent': 8,
#          'Pearce': 2,
#          'Riley': 4,
#          'Honore': 1,
#          'Macarthur': 1,
#          'Gould': 5,
#          'Medvedev': 1,
#          'Sholes': 1,
#          'Rolon': 1,
#          'Bligh': 1,
#          'Lamble': 1,
#          'Jose': 1,
#          'Howard': 3,
#          'Onwuamaeze': 6,
#          ...})

# %%
df['Surname']=le.fit_transform(df['Surname'])

# %%
count(df['Surname'])
# Out:
# Counter({1115: 1,
#          1177: 17,
#          2040: 8,
#          289: 14,
#          1822: 20,
#          537: 22,
#          177: 4,
#          2000: 2,
#          1146: 18,
#          1081: 19,
#          195: 1,
#          83: 6,
#          1369: 5,
#          515: 16,
#          2389: 29,
#          1021: 1,
#          2307: 1,
#          1154: 16,
#          1872: 1,
#          1108: 12,
#          1736: 19,
#          697: 13,
#          991: 2,
#          1862: 1,
#          2880: 14,
#          1642: 24,
#          2897: 20,
#          1908: 6,
#          1772: 2,
#          1609: 11,
#          133: 5,
#          2007: 4,
#          2364: 4,
#          1655: 2,
#          567: 9,
#          1587: 15,
#          2775: 20,
#          1594: 12,
#          105: 1,
#          396: 19,
#          1231: 8,
#          564: 4,
#          2067: 6,
#          1508: 1,
#          241: 10,
#          2668: 4,
#          1689: 29,
#          2016: 3,
#          2888: 11,
#          347: 14,
#          477: 3,
#          2645: 20,
#          1983: 4,
#          2115: 4,
#          2895: 1,
#          2164: 1,
#          2657: 17,
#          812: 17,
#          2570: 18,
#          2720: 1,
#          1252: 13,
#          563: 16,
#          1320: 1,
#          2177: 14,
#          1312: 9,
#          1095: 3,
#          338: 2,
#          473: 5,
#          1010: 1,
#          2179: 16,
#          1438: 4,
#          1754: 1,
#          2101: 12,
#          150: 3,
#          2754: 19,
#          428: 2,
#          1237: 12,
#          2243: 3,
#          380: 1,
#          2201: 1,
#          358: 1,
#          1541: 5,
#          1811: 7,
#          2064: 5,
#          208: 1,
#          1906: 3,
#          965: 1,
#          2321: 7,
#          2417: 3,
#          1147: 1,
#          2287: 11,
#          586: 4,
#          403: 14,
#          887: 14,
#          1046: 20,
#          2903: 1,
#          61: 1,
#          852: 23,
#          942: 16,
#          1250: 15,
#          311: 8,
#          763: 1,
#          1705: 1,
#          2525: 1,
#          2122: 6,
#          2752: 1,
#          2568: 13,
#          817: 1,
#          2322: 2,
#          2597: 6,
#          490: 5,
#          1429: 19,
#          2788: 5,
#          764: 19,
#          481: 5,
#          2857: 16,
#          647: 1,
#          1388: 20,
#          392: 16,
#          2913: 11,
#          944: 7,
#          1623: 13,
#          2167: 13,
#          875: 1,
#          1363: 4,
#          576: 17,
#          46: 4,
#          521: 3,
#          114: 1,
#          1549: 12,
#          1621: 23,
#          464: 14,
#          2716: 2,
#          1074: 1,
#          2601: 18,
#          919: 1,
#          1061: 1,
#          2582: 15,
#          1654: 6,
#          224: 1,
#          2032: 6,
#          546: 5,
#          1123: 5,
#          1849: 4,
#          52: 6,
#          1793: 2,
#          1249: 5,
#          1812: 13,
#          532: 10,
#          566: 3,
#          499: 4,
#          2822: 4,
#          2786: 19,
#          2636: 1,
#          2581: 1,
#          2434: 2,
#          2580: 1,
#          2297: 12,
#          2173: 14,
#          2846: 15,
#          1134: 7,
#          2549: 21,
#          2896: 1,
#          2607: 12,
#          2319: 8,
#          1183: 11,
#          2017: 7,
#          398: 13,
#          117: 2,
#          2326: 1,
#          1230: 18,
#          2009: 5,
#          451: 14,
#          2569: 13,
#          916: 6,
#          1686: 15,
#          2656: 7,
#          2054: 7,
#          1025: 2,
#          2204: 1,
#          633: 19,
#          48: 1,
#          1841: 7,
#          2359: 3,
#          1322: 4,
#          2739: 1,
#          492: 4,
#          1348: 1,
#          2045: 3,
#          1005: 8,
#          1460: 16,
#          593: 5,
#          1082: 2,
#          715: 3,
#          2646: 16,
#          2574: 14,
#          1009: 1,
#          1808: 20,
#          1441: 3,
#          1675: 9,
#          1807: 13,
#          2436: 25,
#          1138: 8,
#          2867: 13,
#          1751: 17,
#          2523: 16,
#          2198: 4,
#          140: 1,
#          439: 13,
#          427: 15,
#          1993: 3,
#          1606: 8,
#          2280: 1,
#          933: 8,
#          2405: 3,
#          886: 1,
#          2473: 32,
#          760: 4,
#          2090: 1,
#          2565: 2,
#          1335: 17,
#          2522: 6,
#          1047: 17,
#          170: 6,
#          1750: 10,
#          1649: 2,
#          1273: 2,
#          1011: 1,
#          719: 1,
#          2813: 1,
#          1552: 12,
#          1242: 20,
#          1857: 12,
#          1703: 5,
#          458: 2,
#          2868: 16,
#          1415: 1,
#          2313: 7,
#          1327: 1,
#          1269: 3,
#          1859: 1,
#          2316: 14,
#          2260: 1,
#          1361: 14,
#          441: 16,
#          2755: 3,
#          881: 1,
#          759: 1,
#          237: 1,
#          306: 17,
#          1927: 2,
#          303: 1,
#          753: 3,
#          2628: 13,
#          471: 7,
#          63: 6,
#          1350: 12,
#          2830: 1,
#          1117: 7,
#          1238: 12,
#          2756: 1,
#          674: 17,
#          1986: 5,
#          1949: 7,
#          24: 4,
#          293: 6,
#          538: 14,
#          2415: 12,
#          1334: 22,
#          934: 4,
#          790: 3,
#          1126: 3,
#          391: 13,
#          527: 17,
#          318: 6,
#          2048: 3,
#          1167: 2,
#          145: 6,
#          745: 6,
#          2187: 1,
#          2338: 7,
#          2463: 4,
#          2296: 16,
#          124: 6,
#          1741: 1,
#          2134: 3,
#          1037: 19,
#          2653: 15,
#          1615: 19,
#          2900: 13,
#          2112: 1,
#          2571: 12,
#          1715: 15,
#          1470: 14,
#          192: 1,
#          1232: 16,
#          860: 2,
#          1426: 4,
#          683: 4,
#          1236: 14,
#          1969: 7,
#          1394: 20,
#          1683: 1,
#          2803: 23,
#          336: 26,
#          2337: 12,
#          2396: 4,
#          2907: 3,
#          908: 1,
#          1283: 3,
#          2206: 9,
#          75: 1,
#          2249: 5,
#          2453: 14,
#          2268: 9,
#          2796: 6,
#          459: 8,
#          1652: 4,
#          1268: 3,
#          1958: 2,
#          264: 3,
#          1829: 8,
#          2552: 14,
#          322: 6,
#          1062: 6,
#          89: 11,
#          968: 5,
#          723: 1,
#          858: 3,
#          1805: 8,
#          304: 3,
#          2059: 1,
#          259: 15,
#          2033: 5,
#          1054: 17,
#          2804: 4,
#          1284: 4,
#          2065: 3,
#          651: 10,
#          699: 1,
#          435: 1,
#          460: 13,
#          1423: 8,
#          1850: 1,
#          2078: 1,
#          2665: 10,
#          2098: 19,
#          410: 10,
#          867: 2,
#          912: 1,
#          2208: 2,
#          927: 7,
#          1756: 16,
#          2172: 1,
#          892: 2,
#          468: 14,
#          1860: 1,
#          1234: 15,
#          1150: 5,
#          689: 3,
#          2271: 2,
#          893: 1,
#          829: 1,
#          1503: 1,
#          556: 17,
#          2697: 1,
#          1970: 4,
#          1467: 1,
#          2178: 13,
#          1669: 17,
#          591: 5,
#          411: 5,
#          1228: 15,
#          884: 17,
#          545: 11,
#          984: 25,
#          2562: 4,
#          2681: 3,
#          2117: 1,
#          2314: 18,
#          2029: 1,
#          2666: 5,
#          2696: 6,
#          608: 5,
#          1923: 1,
#          2671: 3,
#          437: 10,
#          1178: 2,
#          2350: 14,
#          808: 7,
#          2612: 1,
#          1542: 12,
#          2586: 1,
#          474: 4,
#          833: 10,
#          816: 6,
#          332: 8,
#          2093: 11,
#          1113: 1,
#          1871: 12,
#          801: 2,
#          90: 2,
#          1978: 2,
#          123: 7,
#          374: 18,
#          2003: 6,
#          989: 3,
#          1547: 5,
#          662: 2,
#          414: 3,
#          1411: 3,
#          1218: 4,
#          2797: 1,
#          1087: 5,
#          1459: 2,
#          2486: 3,
#          176: 7,
#          2395: 1,
#          530: 5,
#          1611: 1,
#          2675: 11,
#          2677: 4,
#          2079: 1,
#          1572: 20,
#          1407: 18,
#          915: 16,
#          1643: 13,
#          995: 3,
#          1301: 1,
#          219: 2,
#          2717: 2,
#          2384: 3,
#          1424: 1,
#          1628: 2,
#          2778: 5,
#          1248: 2,
#          462: 3,
#          1464: 16,
#          1605: 22,
#          1943: 5,
#          2760: 8,
#          147: 3,
#          1660: 21,
#          877: 1,
#          2686: 4,
#          686: 10,
#          673: 11,
#          1431: 7,
#          1569: 3,
#          2125: 11,
#          1098: 11,
#          1281: 6,
#          2252: 1,
#          2210: 5,
#          340: 7,
#          2548: 1,
#          1520: 5,
#          2793: 1,
#          1637: 9,
#          2140: 1,
#          246: 1,
#          2587: 15,
#          1847: 9,
#          1340: 2,
#          2654: 12,
#          436: 17,
#          1996: 7,
#          1051: 13,
#          1558: 18,
#          1206: 2,
#          727: 1,
#          1753: 19,
#          2262: 1,
#          2274: 1,
#          207: 2,
#          2066: 3,
#          2930: 2,
#          1973: 9,
#          2022: 5,
#          449: 7,
#          349: 2,
#          1586: 11,
#          2672: 3,
#          583: 1,
#          51: 3,
#          846: 11,
#          1240: 8,
#          2534: 1,
#          371: 7,
#          442: 1,
#          1515: 7,
#          215: 12,
#          1119: 2,
#          1863: 13,
#          128: 2,
#          1618: 1,
#          993: 2,
#          1497: 3,
#          1583: 12,
#          2516: 1,
#          1077: 1,
#          630: 11,
#          1521: 3,
#          42: 1,
#          2226: 4,
#          1763: 14,
#          2168: 6,
#          1814: 1,
#          741: 15,
#          1330: 5,
#          212: 11,
#          1661: 1,
#          2097: 11,
#          866: 17,
#          737: 12,
#          447: 8,
#          1674: 10,
#          797: 4,
#          661: 7,
#          2188: 3,
#          2531: 1,
#          1551: 14,
#          80: 19,
#          533: 3,
#          1673: 18,
#          2349: 9,
#          900: 18,
#          1075: 1,
#          1895: 13,
#          86: 3,
#          450: 4,
#          1226: 8,
#          31: 1,
#          2700: 4,
#          1604: 2,
#          2470: 2,
#          267: 1,
#          1362: 20,
#          2811: 1,
#          2795: 1,
#          1317: 3,
#          2088: 8,
#          2259: 3,
#          2216: 5,
#          266: 1,
#          1967: 8,
#          1176: 1,
#          13: 3,
#          726: 2,
#          1629: 1,
#          2774: 5,
#          1821: 1,
#          870: 1,
#          2074: 3,
#          1665: 3,
#          221: 12,
#          2151: 1,
#          516: 3,
#          1896: 9,
#          781: 1,
#          2751: 28,
#          2510: 6,
#          803: 1,
#          2629: 11,
#          2375: 5,
#          1843: 4,
#          1390: 7,
#          612: 3,
#          1716: 13,
#          891: 1,
#          2546: 5,
#          313: 4,
#          1931: 8,
#          1028: 2,
#          2028: 1,
#          1357: 5,
#          522: 3,
#          2034: 2,
#          1321: 12,
#          2209: 3,
#          2085: 4,
#          580: 2,
#          2195: 3,
#          1804: 11,
#          2575: 17,
#          2305: 10,
#          677: 11,
#          2061: 8,
#          983: 1,
#          528: 1,
#          1413: 2,
#          2420: 17,
#          2023: 6,
#          2044: 3,
#          1869: 1,
#          134: 9,
#          1955: 7,
#          119: 1,
#          2655: 19,
#          1387: 4,
#          220: 2,
#          2825: 14,
#          276: 2,
#          2181: 1,
#          2506: 1,
#          417: 8,
#          1336: 16,
#          1939: 4,
#          1739: 1,
#          2429: 20,
#          98: 5,
#          2077: 6,
#          701: 3,
#          2083: 6,
#          2089: 17,
#          2723: 1,
#          230: 19,
#          2080: 1,
#          1217: 10,
#          955: 3,
#          778: 4,
#          1878: 11,
#          149: 8,
#          2737: 2,
#          2576: 11,
#          2147: 3,
#          929: 14,
#          64: 1,
#          1203: 3,
#          2269: 4,
#          628: 9,
#          1285: 5,
#          49: 13,
#          2166: 7,
#          1929: 10,
#          1118: 2,
#          465: 3,
#          1465: 10,
#          957: 4,
#          2916: 3,
#          1571: 5,
#          2104: 8,
#          438: 13,
#          129: 1,
#          2638: 7,
#          1432: 1,
#          2019: 3,
#          1977: 2,
#          110: 3,
#          826: 13,
#          1: 1,
#          130: 1,
#          2689: 1,
#          560: 1,
#          1557: 1,
#          2761: 17,
#          2155: 1,
#          165: 7,
#          1922: 1,
#          1279: 2,
#          1486: 1,
#          1746: 21,
#          2175: 2,
#          2013: 3,
#          2679: 6,
#          2303: 1,
#          419: 1,
#          1988: 1,
#          2222: 4,
#          2096: 8,
#          2508: 6,
#          201: 3,
#          2422: 13,
#          1709: 4,
#          2390: 1,
#          1162: 3,
#          1405: 1,
#          2467: 2,
#          111: 3,
#          179: 1,
#          2856: 24,
#          1839: 22,
#          2551: 18,
#          1781: 1,
#          1820: 3,
#          550: 5,
#          2918: 6,
#          2038: 7,
#          2289: 2,
#          1941: 13,
#          226: 4,
#          2844: 2,
#          2594: 1,
#          523: 6,
#          1313: 4,
#          1479: 5,
#          2030: 3,
#          469: 5,
#          2871: 1,
#          2599: 2,
#          1428: 1,
#          180: 2,
#          2430: 2,
#          127: 3,
#          1235: 11,
#          348: 1,
#          2878: 25,
#          2099: 1,
#          2864: 13,
#          2386: 4,
#          2753: 9,
#          261: 6,
#          2812: 1,
#          249: 4,
#          325: 1,
#          440: 13,
#          2906: 1,
#          1329: 4,
#          2814: 2,
#          1916: 3,
#          1769: 1,
#          589: 6,
#          228: 8,
#          999: 5,
#          2818: 2,
#          2458: 15,
#          352: 1,
#          2094: 12,
#          2100: 20,
#          2106: 19,
#          1389: 1,
#          2499: 3,
#          1535: 4,
#          672: 1,
#          1233: 17,
#          1006: 1,
#          2493: 2,
#          1667: 17,
#          109: 2,
#          1106: 4,
#          1499: 1,
#          2082: 5,
#          1887: 11,
#          798: 2,
#          131: 4,
#          2363: 7,
#          776: 2,
#          163: 1,
#          2573: 4,
#          1034: 1,
#          2920: 1,
#          972: 2,
#          1901: 3,
#          946: 1,
#          1720: 1,
#          2929: 1,
#          843: 1,
#          457: 1,
#          2740: 7,
#          9: 5,
#          493: 12,
#          2605: 1,
#          2826: 1,
#          1093: 15,
#          2541: 16,
#          33: 7,
#          543: 4,
#          1483: 1,
#          1421: 1,
#          2278: 1,
#          678: 7,
#          1292: 4,
#          717: 2,
#          997: 17,
#          1260: 9,
#          1151: 1,
#          1314: 20,
#          497: 6,
#          366: 5,
#          2849: 10,
#          272: 1,
#          453: 5,
#          82: 3,
#          2504: 1,
#          2162: 2,
#          2152: 5,
#          907: 1,
#          1636: 7,
#          1694: 4,
#          1761: 7,
#          2593: 21,
#          2610: 1,
#          2041: 4,
#          1817: 4,
#          1904: 5,
#          2519: 9,
#          1026: 5,
#          1874: 1,
#          1016: 6,
#          1964: 1,
#          1221: 1,
#          594: 1,
#          382: 4,
#          2820: 1,
#          314: 5,
#          92: 1,
#          2492: 1,
#          1778: 4,
#          2050: 2,
#          876: 9,
#          1145: 1,
#          1112: 6,
#          711: 7,
#          1191: 5,
#          732: 9,
#          2360: 1,
#          1664: 1,
#          894: 1,
#          2873: 4,
#          7: 1,
#          700: 1,
#          1513: 1,
#          334: 5,
#          1277: 3,
#          151: 1,
#          779: 1,
#          1550: 11,
#          707: 1,
#          2824: 12,
#          1099: 7,
#          2821: 2,
#          1589: 11,
#          1666: 11,
#          2838: 2,
#          2524: 12,
#          1888: 15,
#          2284: 1,
#          2076: 5,
#          2592: 8,
#          2810: 2,
#          2639: 12,
#          1762: 1,
#          47: 3,
#          158: 2,
#          2891: 5,
#          2488: 3,
#          822: 1,
#          2709: 1,
#          1956: 4,
#          1803: 12,
#          2116: 5,
#          636: 12,
#          728: 8,
#          2682: 3,
#          236: 6,
#          1992: 1,
#          2158: 1,
#          2068: 5,
#          1884: 1,
#          1278: 3,
#          2908: 1,
#          479: 4,
#          1608: 12,
#          2901: 4,
#          2748: 6,
#          2403: 1,
#          1116: 1,
#          2449: 3,
#          362: 1,
#          605: 9,
#          2457: 5,
#          416: 7,
#          761: 2,
#          2142: 7,
#          748: 1,
#          2640: 2,
#          1476: 13,
#          1349: 1,
#          2070: 6,
#          842: 2,
#          2659: 10,
#          2670: 3,
#          1364: 2,
#          1953: 5,
#          878: 16,
#          73: 4,
#          1414: 1,
#          1067: 5,
#          1590: 1,
#          1771: 1,
#          581: 1,
#          637: 1,
#          730: 1,
#          840: 1,
#          290: 2,
#          2713: 3,
#          1468: 4,
#          277: 2,
#          1854: 1,
#          2738: 1,
#          2567: 5,
#          2840: 2,
#          2413: 1,
#          346: 7,
#          1144: 5,
#          1570: 12,
#          1055: 9,
#          1959: 6,
#          542: 8,
#          862: 4,
#          2253: 8,
#          2842: 1,
#          2518: 3,
#          938: 4,
#          882: 2,
#          2542: 1,
#          1347: 1,
#          694: 3,
#          1409: 1,
#          2039: 4,
#          1036: 3,
#          2602: 2,
#          397: 1,
#          739: 1,
#          2662: 19,
#          187: 4,
#          2301: 4,
#          388: 5,
#          28: 8,
#          1634: 1,
#          2456: 12,
#          2207: 1,
#          1505: 1,
#          387: 1,
#          2742: 4,
#          2176: 3,
#          2540: 1,
#          2107: 7,
#          2446: 6,
#          1607: 10,
#          2556: 1,
#          2223: 1,
#          1610: 1,
#          1500: 1,
#          1484: 1,
#          1351: 11,
#          54: 5,
#          540: 5,
#          1721: 1,
#          2018: 6,
#          1287: 1,
#          1909: 7,
#          721: 3,
#          1632: 1,
#          112: 2,
#          1382: 12,
#          2254: 7,
#          2015: 5,
#          2428: 1,
#          1493: 1,
#          1219: 2,
#          825: 1,
#          160: 1,
#          2084: 5,
#          2688: 3,
#          2515: 1,
#          30: 8,
#          45: 3,
#          1068: 2,
#          1767: 1,
#          343: 12,
#          2021: 2,
#          1823: 1,
#          1748: 1,
#          848: 1,
#          1700: 6,
#          1353: 2,
#          2902: 4,
#          1315: 1,
#          1110: 1,
#          2847: 1,
#          494: 6,
#          518: 4,
#          350: 2,
#          898: 1,
#          2130: 3,
#          2733: 8,
#          2133: 2,
#          2279: 4,
#          1200: 1,
#          1627: 1,
#          1044: 5,
#          1777: 1,
#          2441: 1,
#          2304: 1,
#          269: 1,
#          1482: 1,
#          1341: 1,
#          1220: 3,
#          2047: 6,
#          ...})

# %%
df
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 0             1    15634602     1115          619          0  Female  37.0
# 1             2    15647311     1177          608          2  Female  37.0
# 2             3    15619304     2040          502          0  Female  37.0
# 3             4    15701354      289          699          0  Female  37.0
# 4             5    15737888     1822          850          2  Female  37.0
# ...         ...         ...      ...          ...        ...     ...   ...
# 9995       9996    15606229     1999          771          0    Male  37.0
# 9996       9997    15569892     1336          516          0    Male  35.0
# 9997       9998    15584532     1570          709          0  Female  36.0
# 9998       9999    15682355     2345          772          1    Male  37.0
# 9999      10000    15628319     2751          792          0  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Method 2 (Feature map)

# %%
count(df['NumOfProducts'])
# Out:
# Counter({1: 5084, 3: 266, 2: 4590, 4: 60})

# %%
df['NumOfProducts']=df['NumOfProducts'].replace(['No','Yes'],[0,1])

# %%
count(df['NumOfProducts'])
# Out:
# Counter({1: 5084, 3: 266, 2: 4590, 4: 60})

# %% [markdown]
# # Method 3 (One hot encoding)

# %%
df['Geography']
# Out:
# 0       0
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    1
# 9999    0
# Name: Geography, Length: 10000, dtype: int64

# %%
Geography = pd.get_dummies(df['Geography'],prefix='Geography')

# %%
Geography
# Out:
#       Geography_0  Geography_1  Geography_2
# 0               1            0            0
# 1               0            0            1
# 2               1            0            0
# 3               1            0            0
# 4               0            0            1
# ...           ...          ...          ...
# 9995            1            0            0
# 9996            1            0            0
# 9997            1            0            0
# 9998            0            1            0
# 9999            1            0            0
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Split the data into dependent and independent variables in python

# %%
x= df.iloc[ : , :-1]

y= df.iloc[ : , 4]
x
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 0             1    15634602     1115          619          0  Female  37.0
# 1             2    15647311     1177          608          2  Female  37.0
# 2             3    15619304     2040          502          0  Female  37.0
# 3             4    15701354      289          699          0  Female  37.0
# 4             5    15737888     1822          850          2  Female  37.0
# ...         ...         ...      ...          ...        ...     ...   ...
# 9995       9996    15606229     1999          771          0    Male  37.0
# 9996       9997    15569892     1336          516          0    Male  35.0
# 9997       9998    15584532     1570          709          0  Female  36.0
# 9998       9999    15682355     2345          772          1    Male  37.0
# 9999      10000    15628319     2751          792          0  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 13 columns]

# %%
y
# Out:
# 0       0
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    1
# 9999    0
# Name: Geography, Length: 10000, dtype: int64

# %%
x= df.iloc[ 1:2 , :-1]
x
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 1          2    15647311     1177          608          2  Female  37.0
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 1       1  83807.86              1          0               1        112542.58

# %% [markdown]
# #scaling the independent variable

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
x=df.iloc[:,0:3]
y=df['NumOfProducts']
x
# Out:
#       RowNumber  CustomerId  Surname
# 0             1    15634602     1115
# 1             2    15647311     1177
# 2             3    15619304     2040
# 3             4    15701354      289
# 4             5    15737888     1822
# ...         ...         ...      ...
# 9995       9996    15606229     1999
# 9996       9997    15569892     1336
# 9997       9998    15584532     1570
# 9998       9999    15682355     2345
# 9999      10000    15628319     2751
#
# [10000 rows x 3 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       3
# 3       2
# 4       1
#        ..
# 9995    2
# 9996    1
# 9997    1
# 9998    2
# 9999    1
# Name: NumOfProducts, Length: 10000, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=11)

# %%
xtrain
# Out:
#       RowNumber  CustomerId  Surname
# 1264       1265    15732199      993
# 5376       5377    15602500     1694
# 2037       2038    15678146     2845
# 6485       6486    15635197     1016
# 1600       1601    15748718     1037
# ...         ...         ...      ...
# 1293       1294    15687752     1067
# 4023       4024    15629187     2611
# 7259       7260    15718921     1183
# 5200       5201    15641298      617
# 3775       3776    15709004     1660
#
# [7000 rows x 3 columns]

# %%
xtest
# Out:
#       RowNumber  CustomerId  Surname
# 3104       3105    15654230     1808
# 6353       6354    15676353      831
# 8689       8690    15684769     2808
# 5857       5858    15813659      909
# 6011       6012    15783007     2113
# ...         ...         ...      ...
# 8125       8126    15666982     2496
# 8444       8445    15793641      839
# 2167       2168    15780846     2248
# 8043       8044    15616525     2485
# 4917       4918    15681991     2758
#
# [3000 rows x 3 columns]

# %%
st = StandardScaler()
nm = MinMaxScaler()

# %%
s_xtrain = st.fit_transform(xtrain)
s_xtrain
# Out:
# array([[-1.29671985,  0.57944472, -0.60566716],
#        [ 0.12810842, -1.2259028 ,  0.22108595],
#        [-1.02887154, -0.17294697,  1.57856501],
#        ...,
#        [ 0.7805772 ,  0.39462137, -0.38158287],
#        [ 0.06712355, -0.68585335, -1.04911819],
#        [-0.42664597,  0.25658151,  0.18098665]])

# %% [markdown]
# #Split the data into training and testing

# %%
s_xtest = st.transform(xtest)

# %%
s_xtest
# Out:
# array([[-0.65915078, -0.50584615,  0.35553652],
#        [ 0.46664373, -0.19790466, -0.79672851],
#        [ 1.27607924, -0.080758  ,  1.53492754],
#        ...,
#        [-0.9838259 ,  1.2565875 ,  0.87446857],
#        [ 1.05223706, -1.03068157,  1.15398424],
#        [-0.03093735, -0.11942642,  1.47595799]])

# %%
n_xtrain = nm.fit_transform(xtrain)
n_xtrain
# Out:
# array([[0.12642529, 0.66600394, 0.33879222],
#        [0.53770754, 0.14715813, 0.57795974],
#        [0.20374075, 0.44977118, 0.97065848],
#        ...,
#        [0.72604521, 0.61288684, 0.40361651],
#        [0.52010402, 0.30236503, 0.21050836],
#        [0.37757552, 0.57321503, 0.5663596 ]])

# %%
n_xtest = nm.transform(xtest)
n_xtest
# Out:
# array([[0.31046209, 0.35409799, 0.61685432],
#        [0.63542709, 0.44259849, 0.28352098],
#        [0.86907381, 0.47626572, 0.9580348 ],
#        ...,
#        [0.21674335, 0.86061062, 0.76697373],
#        [0.80446089, 0.20326351, 0.8478335 ],
#        [0.49179836, 0.46515265, 0.94097578]])
